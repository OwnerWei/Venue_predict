# %%
import os
import subprocess

# %%
directory = os.listdir('/home/wei/TestData/WavSet/')

# %%
dist_dir = os.listdir('/home/wei/TestData/Wav/')

# %%
file_path = '/home/wei/TestData/Wav/'

# %%
for f in directory:
    print f
    if 'ERROR' not in f and f not in dist_dir:
        subprocess.check_output('ffmpeg -i /home/wei/TestData/WavSet/'+f+' -ar 22505 -ac 1 /home/wei/TestData/Wav/'+f, shell=True)
    else:
        print 'error %s'%(f)
# Out:
# 3198_6UINBP6cmC8.wav
# error 3198_6UINBP6cmC8.wav
# 1765_3-_QS346VWo.wav
# error 1765_3-_QS346VWo.wav
# 3573_7RaP0v6zRcM.wav
# error 3573_7RaP0v6zRcM.wav
# 6917_GJvWWCx2UuU.wav
# error 6917_GJvWWCx2UuU.wav
# 2390_4Yc71_dU3m4.wav
# error 2390_4Yc71_dU3m4.wav
# 3459_78qlcOgPZ9U.wav
# error 3459_78qlcOgPZ9U.wav
# 2126_3uW51_sFnrw.wav
# error 2126_3uW51_sFnrw.wav
# 6019_DtdUYobU_EI.wav
# error 6019_DtdUYobU_EI.wav
# 3059_66pL4oeEWGE.wav
# error 3059_66pL4oeEWGE.wav
# 1832_39hw3q5ylrY.wav
# error 1832_39hw3q5ylrY.wav
# 3217_6WkNa8RbL9E.wav
# error 3217_6WkNa8RbL9E.wav
# 3614_7ZW8xO37bA4.wav
# error 3614_7ZW8xO37bA4.wav
# 2812_5ZX1-GAb7IM.wav
# error 2812_5ZX1-GAb7IM.wav
# 2191_45ovArCxLMc.wav
# error 2191_45ovArCxLMc.wav
# 142_-H5kC4WsuI8.wav
# error 142_-H5kC4WsuI8.wav
# 5510_CVbd86Xi1a0.wav
# error 5510_CVbd86Xi1a0.wav
# 1001_1FnT0RrfMEA.wav
# error 1001_1FnT0RrfMEA.wav
# 5623_CmhOf7i4kVk.wav
# error 5623_CmhOf7i4kVk.wav
# 5868_DS13-KbbDCs.wav
# error 5868_DS13-KbbDCs.wav
# ...
